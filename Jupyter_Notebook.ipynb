# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ## Data Science Tool and Ecosystem

# %% [markdown]
# in this notebook, data science and ecosystem are summarized

# %% [markdown]
# popular data science languages.
# 1. Python
# 2. SQL
# 3. Java
# 4. Scala
# 5. C++
# 6. Go

# %% [markdown]
# Commonly used list data science libraries.
# 1. numpy
# 2. PyTorch
# 3. Pandas
# 4. SciPy
# 5. Matplotlib
# 6. Seaborn
# 7. Scikit-learn
# 8. Keras

# %% [markdown]
# | Data Science Tools|
# |:--------:|
# | Spyder |
# |  Rstudio  |
# |  Anaconda  |

# %% [markdown]
# Below examples of arithmetic expressions

# %%
(2+6)*2 + 1
# Out:
# 17

# %%
# minutes to hours
min = input('insert number of minutes:')
hour = int(min)/60
print("minutes:", min, ", thus hours:", str(hour))
# Out:
# minutes: 200 , thus hours: 3.3333333333333335

# %% [markdown]
# **Objectives**
# * List Commonly used list data science libraries
# * List popular data science languages.
# * List other requirements

# %% [markdown]
# # Author
# Enrico Trotti
